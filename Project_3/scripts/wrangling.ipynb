# %%
import pandas as pd

# %%
import numpy as np

# %%
# Read in the client demographics data
client_read_df = pd.read_csv(
    "https://raw.githubusercontent.com/biodatascience/datasci611/gh-pages/data/project2_2019/CLIENT_191102.tsv",      # relative python path to subdirectory
    sep='\t'           # Tab-separated value file.
    #quotechar="'",        # single quote allowed as quote character
    #dtype={"salary": int},             # Parse the salary column as an integer 
    ,usecols=['Client ID', 'Client Age at Entry', 'Client Gender', 'Client Primary Race','Client Ethnicity','Client Veteran Status']   # Only load the three columns specified.
    #parse_dates=['birth_date'],     # Intepret the birth_date column as a date
    #,skiprows=10        # Skip the first 10 rows of the file
 ,na_values=['**']       # Take any '.' or '??' values as NA
,header=0
).drop_duplicates()

client_read_df
#client_total_rows = client_df.count
#print (client_total_rows)
# Out:
#       Client ID  Client Age at Entry Client Gender  \
# 0        397941                 60.0        Female
# 1        130335                 48.0        Female
# 2        188933                 42.0        Female
# 3        168290                 57.0          Male
# 4        123122                 51.0          Male
# ...         ...                  ...           ...
# 5284     363078                 62.0          Male
# 5285     291392                 55.0          Male
# 5286     382261                 49.0          Male
# 5287     359808                 59.0          Male
# 5288     385539                 58.0          Male
#
#                   Client Primary Race               Client Ethnicity  \
# 0                         White (HUD)  Non-Hispanic/Non-Latino (HUD)
# 1     Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
# 2     Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
# 3                         White (HUD)          Hispanic/Latino (HUD)
# 4                         White (HUD)  Non-Hispanic/Non-Latino (HUD)
# ...                               ...                            ...
# 5284  Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
# 5285  Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
# 5286  Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
# 5287  Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
# 5288  Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
#
#      Client Veteran Status
# 0                 No (HUD)
# 1                 No (HUD)
# 2                 No (HUD)
# 3                 No (HUD)
# 4                 No (HUD)
# ...                    ...
# 5284             Yes (HUD)
# 5285             Yes (HUD)
# 5286             Yes (HUD)
# 5287             Yes (HUD)
# 5288             Yes (HUD)
#
# [3204 rows x 6 columns]

# %%
#Update columns names
client_read_df.columns=['ClientID', 'Age', 'Gender', 'Race','Ethnicity','VeteranStatus']

#client_csv = client_df.to_csv (r'data\client.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
client_read_df
# Out:
#       ClientID   Age  Gender                             Race  \
# 0       397941  60.0  Female                      White (HUD)
# 1       130335  48.0  Female  Black or African American (HUD)
# 2       188933  42.0  Female  Black or African American (HUD)
# 3       168290  57.0    Male                      White (HUD)
# 4       123122  51.0    Male                      White (HUD)
# ...        ...   ...     ...                              ...
# 5284    363078  62.0    Male  Black or African American (HUD)
# 5285    291392  55.0    Male  Black or African American (HUD)
# 5286    382261  49.0    Male  Black or African American (HUD)
# 5287    359808  59.0    Male  Black or African American (HUD)
# 5288    385539  58.0    Male  Black or African American (HUD)
#
#                           Ethnicity VeteranStatus
# 0     Non-Hispanic/Non-Latino (HUD)      No (HUD)
# 1     Non-Hispanic/Non-Latino (HUD)      No (HUD)
# 2     Non-Hispanic/Non-Latino (HUD)      No (HUD)
# 3             Hispanic/Latino (HUD)      No (HUD)
# 4     Non-Hispanic/Non-Latino (HUD)      No (HUD)
# ...                             ...           ...
# 5284  Non-Hispanic/Non-Latino (HUD)     Yes (HUD)
# 5285  Non-Hispanic/Non-Latino (HUD)     Yes (HUD)
# 5286  Non-Hispanic/Non-Latino (HUD)     Yes (HUD)
# 5287  Non-Hispanic/Non-Latino (HUD)     Yes (HUD)
# 5288  Non-Hispanic/Non-Latino (HUD)     Yes (HUD)
#
# [3204 rows x 6 columns]

# %%
#Update values for better readability
client_read_df = client_read_df.replace(to_replace ="Black or African American (HUD)", value ="Black/African American")
client_read_df = client_read_df.replace(to_replace ="White (HUD)", value ="White")
client_read_df = client_read_df.replace(to_replace ="Non-Hispanic/Non-Latino (HUD)", value ="Non-Hispanic/Non-Latino") 
client_read_df = client_read_df.replace(to_replace ="Asian (HUD)", value ="Asian") 
client_read_df = client_read_df.replace(to_replace ="Native Hawaiian or Other Pacific Islander (HUD)", value ="Native Hawaiian/Pacific Islander") 
client_read_df = client_read_df.replace(to_replace ="Data not collected (HUD)", value ="Unknown") 
client_read_df = client_read_df.replace(to_replace ="Client refused (HUD)", value ="Unknown") 
client_read_df = client_read_df.replace(to_replace ="Client doesn't Know (HUD)", value ="Unknown") 
client_read_df = client_read_df.replace(to_replace ="Hispanic/Latino (HUD)", value ="Hispanic/Latino") 
client_read_df = client_read_df.replace(to_replace ="Yes (HUD)", value ="Yes") 
client_read_df = client_read_df.replace(to_replace ="No (HUD)", value ="No") 

#Convert age to int
#client_read_df['Age'] = client_read_df['Age'].astype(int)

client_read_df
# Out:
#       ClientID   Age  Gender                    Race                Ethnicity  \
# 0       397941  60.0  Female                   White  Non-Hispanic/Non-Latino
# 1       130335  48.0  Female  Black/African American  Non-Hispanic/Non-Latino
# 2       188933  42.0  Female  Black/African American  Non-Hispanic/Non-Latino
# 3       168290  57.0    Male                   White          Hispanic/Latino
# 4       123122  51.0    Male                   White  Non-Hispanic/Non-Latino
# ...        ...   ...     ...                     ...                      ...
# 5284    363078  62.0    Male  Black/African American  Non-Hispanic/Non-Latino
# 5285    291392  55.0    Male  Black/African American  Non-Hispanic/Non-Latino
# 5286    382261  49.0    Male  Black/African American  Non-Hispanic/Non-Latino
# 5287    359808  59.0    Male  Black/African American  Non-Hispanic/Non-Latino
# 5288    385539  58.0    Male  Black/African American  Non-Hispanic/Non-Latino
#
#      VeteranStatus
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ...            ...
# 5284           Yes
# 5285           Yes
# 5286           Yes
# 5287           Yes
# 5288           Yes
#
# [3204 rows x 6 columns]

# %%
#Create distinct client list using the max age recorded

client_maxage_df = client_read_df.groupby(['ClientID'], sort=False)['Age'].max()
client_maxage_df
# Out:
# ClientID
# 397941    60.0
# 130335    48.0
# 188933    42.0
# 168290    61.0
# 123122    53.0
#           ...
# 376797    51.0
# 199296    38.0
# 378312    50.0
# 379142    33.0
# 363078    62.0
# Name: Age, Length: 2364, dtype: float64

# %%
client_maxage_df = client_maxage_df.to_frame().reset_index()

client_maxage_df.columns = ['ClientID','Age']

# %%
#Append corresponding demographics to distinct patient list

client_df = pd.merge(client_maxage_df, client_read_df, how='left', left_on = ['ClientID','Age'], right_on = ['ClientID','Age'])

client_df
# Out:
#       ClientID   Age  Gender                    Race                Ethnicity  \
# 0       397941  60.0  Female                   White  Non-Hispanic/Non-Latino
# 1       130335  48.0  Female  Black/African American  Non-Hispanic/Non-Latino
# 2       188933  42.0  Female  Black/African American  Non-Hispanic/Non-Latino
# 3       168290  61.0    Male                   White          Hispanic/Latino
# 4       123122  53.0    Male                   White  Non-Hispanic/Non-Latino
# ...        ...   ...     ...                     ...                      ...
# 2359    376797  51.0    Male  Black/African American  Non-Hispanic/Non-Latino
# 2360    199296  38.0  Female                   White  Non-Hispanic/Non-Latino
# 2361    378312  50.0    Male  Black/African American  Non-Hispanic/Non-Latino
# 2362    379142  33.0    Male                   White  Non-Hispanic/Non-Latino
# 2363    363078  62.0    Male  Black/African American  Non-Hispanic/Non-Latino
#
#      VeteranStatus
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ...            ...
# 2359            No
# 2360            No
# 2361            No
# 2362            No
# 2363           Yes
#
# [2364 rows x 6 columns]

# %%
# Read in the disability data
disability_read_df = pd.read_csv(
    "https://raw.githubusercontent.com/biodatascience/datasci611/gh-pages/data/project2_2019/DISABILITY_ENTRY_191102.tsv",     # relative python path to subdirectory
    sep='\t'           # Tab-separated value file.
    #quotechar="'",        # single quote allowed as quote character
    #dtype={"salary": int},             # Parse the salary column as an integer 
    ,usecols=['Client ID', 'Disability Type (Entry)', 'Disability Start Date (Entry)', 'Disability Determination (Entry)']   # Only load the three columns specified.
    #parse_dates=['birth_date'],     # Intepret the birth_date column as a date
    #skiprows=10,         # Skip the first 10 rows of the file
    ,na_values=['**']       # Take any '.' or '??' values as NA
    ,header=0
)

disability_read_df
# Out:
#        Client ID Disability Determination (Entry)  \
# 0         397941                         No (HUD)
# 1         397941                         No (HUD)
# 2         397941                         No (HUD)
# 3         397941                         No (HUD)
# 4         397941                         No (HUD)
# ...          ...                              ...
# 41388     401495                         No (HUD)
# 41389     401495                         No (HUD)
# 41390     401495                         No (HUD)
# 41391     401495                         No (HUD)
# 41392     401495                         No (HUD)
#
#                  Disability Type (Entry) Disability Start Date (Entry)
# 0                    Alcohol Abuse (HUD)                     4/20/2015
# 1      Both Alcohol and Drug Abuse (HUD)                     4/20/2015
# 2         Chronic Health Condition (HUD)                     4/20/2015
# 3                    Developmental (HUD)                     4/20/2015
# 4                       Drug Abuse (HUD)                     4/20/2015
# ...                                  ...                           ...
# 41388                Developmental (HUD)                      6/3/2015
# 41389                   Drug Abuse (HUD)                      6/3/2015
# 41390                     HIV/AIDS (HUD)                      6/3/2015
# 41391        Mental Health Problem (HUD)                      6/3/2015
# 41392                     Physical (HUD)                      6/3/2015
#
# [41393 rows x 4 columns]

# %%
#Update column names
disability_read_df.columns=['ClientID', 'Determination', 'DisabilityType', 'StartDate']

disability_read_df
# Out:
#        ClientID Determination                     DisabilityType  StartDate
# 0        397941      No (HUD)                Alcohol Abuse (HUD)  4/20/2015
# 1        397941      No (HUD)  Both Alcohol and Drug Abuse (HUD)  4/20/2015
# 2        397941      No (HUD)     Chronic Health Condition (HUD)  4/20/2015
# 3        397941      No (HUD)                Developmental (HUD)  4/20/2015
# 4        397941      No (HUD)                   Drug Abuse (HUD)  4/20/2015
# ...         ...           ...                                ...        ...
# 41388    401495      No (HUD)                Developmental (HUD)   6/3/2015
# 41389    401495      No (HUD)                   Drug Abuse (HUD)   6/3/2015
# 41390    401495      No (HUD)                     HIV/AIDS (HUD)   6/3/2015
# 41391    401495      No (HUD)        Mental Health Problem (HUD)   6/3/2015
# 41392    401495      No (HUD)                     Physical (HUD)   6/3/2015
#
# [41393 rows x 4 columns]

# %%
#filter down to clients that have atleast 1 disability
disability_Yes_df = disability_read_df[disability_read_df['Determination'] == 'Yes (HUD)'].drop_duplicates()

disability_Yes_df.head(10)
# Out:
#     ClientID Determination                  DisabilityType   StartDate
# 7     397941     Yes (HUD)     Mental Health Problem (HUD)   4/20/2015
# 8     397941     Yes (HUD)                Physical/Medical   4/20/2005
# 22    130335     Yes (HUD)  Chronic Health Condition (HUD)   6/13/1996
# 23    130335     Yes (HUD)                Physical/Medical   6/13/2007
# 36    188933     Yes (HUD)                Drug Abuse (HUD)   3/28/2014
# 37    188933     Yes (HUD)     Mental Health Problem (HUD)   3/28/2014
# 38    188933     Yes (HUD)                  Physical (HUD)   3/28/2014
# 39    188933     Yes (HUD)                  Physical (HUD)  12/20/2014
# 40    188933     Yes (HUD)                  Physical (HUD)   8/15/2015
# 49    168290     Yes (HUD)  Chronic Health Condition (HUD)   10/6/2014

# %%
#Drop start date and remove duplicates
disability_pivot_df1 = disability_Yes_df[['ClientID','Determination','DisabilityType']].drop_duplicates()

disability_pivot_df1
# Out:
#        ClientID Determination                  DisabilityType
# 7        397941     Yes (HUD)     Mental Health Problem (HUD)
# 8        397941     Yes (HUD)                Physical/Medical
# 22       130335     Yes (HUD)  Chronic Health Condition (HUD)
# 23       130335     Yes (HUD)                Physical/Medical
# 36       188933     Yes (HUD)                Drug Abuse (HUD)
# ...         ...           ...                             ...
# 40618    367285     Yes (HUD)     Mental Health Problem (HUD)
# 40866    199296     Yes (HUD)     Mental Health Problem (HUD)
# 40875    378312     Yes (HUD)                Physical/Medical
# 40909    379142     Yes (HUD)     Mental Health Problem (HUD)
# 41283    363078     Yes (HUD)                Physical/Medical
#
# [1967 rows x 3 columns]

# %%
#Pivot disability table
disability_pivot_df = disability_pivot_df1.pivot(index = 'ClientID', columns = 'DisabilityType', values = 'Determination').fillna('No (HUD)')

disability_pivot_df
# Out:
# DisabilityType Alcohol Abuse (HUD) Both Alcohol and Drug Abuse (HUD)  \
# ClientID
# 1096                      No (HUD)                          No (HUD)
# 2024                      No (HUD)                          No (HUD)
# 2054                      No (HUD)                          No (HUD)
# 2142                      No (HUD)                         Yes (HUD)
# 2458                      No (HUD)                          No (HUD)
# ...                            ...                               ...
# 1003586                   No (HUD)                          No (HUD)
# 1003772                   No (HUD)                          No (HUD)
# 1004044                   No (HUD)                          No (HUD)
# 1004126                   No (HUD)                          No (HUD)
# 1004212                   No (HUD)                         Yes (HUD)
#
# DisabilityType Chronic Health Condition (HUD) Developmental (HUD)  \
# ClientID
# 1096                                 No (HUD)            No (HUD)
# 2024                                 No (HUD)            No (HUD)
# 2054                                 No (HUD)            No (HUD)
# 2142                                 No (HUD)            No (HUD)
# 2458                                 No (HUD)            No (HUD)
# ...                                       ...                 ...
# 1003586                             Yes (HUD)            No (HUD)
# 1003772                              No (HUD)            No (HUD)
# 1004044                             Yes (HUD)            No (HUD)
# 1004126                              No (HUD)           Yes (HUD)
# 1004212                              No (HUD)            No (HUD)
#
# DisabilityType Drug Abuse (HUD) HIV/AIDS (HUD) Mental Health Problem (HUD)  \
# ClientID
# 1096                   No (HUD)       No (HUD)                    No (HUD)
# 2024                   No (HUD)      Yes (HUD)                    No (HUD)
# 2054                   No (HUD)       No (HUD)                   Yes (HUD)
# 2142                   No (HUD)       No (HUD)                   Yes (HUD)
# 2458                   No (HUD)       No (HUD)                   Yes (HUD)
# ...                         ...            ...                         ...
# 1003586                No (HUD)       No (HUD)                    No (HUD)
# 1003772                No (HUD)       No (HUD)                   Yes (HUD)
# 1004044                No (HUD)       No (HUD)                   Yes (HUD)
# 1004126                No (HUD)       No (HUD)                   Yes (HUD)
# 1004212                No (HUD)       No (HUD)                   Yes (HUD)
#
# DisabilityType     Other Other: Learning Physical (HUD) Physical/Medical  \
# ClientID
# 1096            No (HUD)        No (HUD)      Yes (HUD)         No (HUD)
# 2024            No (HUD)        No (HUD)       No (HUD)         No (HUD)
# 2054            No (HUD)        No (HUD)      Yes (HUD)         No (HUD)
# 2142            No (HUD)        No (HUD)      Yes (HUD)        Yes (HUD)
# 2458            No (HUD)        No (HUD)       No (HUD)         No (HUD)
# ...                  ...             ...            ...              ...
# 1003586         No (HUD)        No (HUD)      Yes (HUD)         No (HUD)
# 1003772         No (HUD)        No (HUD)       No (HUD)         No (HUD)
# 1004044         No (HUD)        No (HUD)      Yes (HUD)         No (HUD)
# 1004126         No (HUD)        No (HUD)       No (HUD)         No (HUD)
# 1004212         No (HUD)        No (HUD)       No (HUD)         No (HUD)
#
# DisabilityType Vision Impaired
# ClientID
# 1096                  No (HUD)
# 2024                  No (HUD)
# 2054                  No (HUD)
# 2142                  No (HUD)
# 2458                  No (HUD)
# ...                        ...
# 1003586               No (HUD)
# 1003772               No (HUD)
# 1004044               No (HUD)
# 1004126               No (HUD)
# 1004212               No (HUD)
#
# [1274 rows x 12 columns]

# %%
#Rename columns
disability_pivot_df.columns=['AlcoholAbuse','AlcoholandDrugAbuse','ChronicHealthCondition','Developmental',
                             'DrugAbuse','HIVorAIDS','MentalHealthProblem','Other','Learning','Physical','PhysicalMedical','VisionImpaired']

disability_pivot_df
# Out:
#          AlcoholAbuse AlcoholandDrugAbuse ChronicHealthCondition  \
# ClientID
# 1096         No (HUD)            No (HUD)               No (HUD)
# 2024         No (HUD)            No (HUD)               No (HUD)
# 2054         No (HUD)            No (HUD)               No (HUD)
# 2142         No (HUD)           Yes (HUD)               No (HUD)
# 2458         No (HUD)            No (HUD)               No (HUD)
# ...               ...                 ...                    ...
# 1003586      No (HUD)            No (HUD)              Yes (HUD)
# 1003772      No (HUD)            No (HUD)               No (HUD)
# 1004044      No (HUD)            No (HUD)              Yes (HUD)
# 1004126      No (HUD)            No (HUD)               No (HUD)
# 1004212      No (HUD)           Yes (HUD)               No (HUD)
#
#          Developmental DrugAbuse  HIVorAIDS MentalHealthProblem     Other  \
# ClientID
# 1096          No (HUD)  No (HUD)   No (HUD)            No (HUD)  No (HUD)
# 2024          No (HUD)  No (HUD)  Yes (HUD)            No (HUD)  No (HUD)
# 2054          No (HUD)  No (HUD)   No (HUD)           Yes (HUD)  No (HUD)
# 2142          No (HUD)  No (HUD)   No (HUD)           Yes (HUD)  No (HUD)
# 2458          No (HUD)  No (HUD)   No (HUD)           Yes (HUD)  No (HUD)
# ...                ...       ...        ...                 ...       ...
# 1003586       No (HUD)  No (HUD)   No (HUD)            No (HUD)  No (HUD)
# 1003772       No (HUD)  No (HUD)   No (HUD)           Yes (HUD)  No (HUD)
# 1004044       No (HUD)  No (HUD)   No (HUD)           Yes (HUD)  No (HUD)
# 1004126      Yes (HUD)  No (HUD)   No (HUD)           Yes (HUD)  No (HUD)
# 1004212       No (HUD)  No (HUD)   No (HUD)           Yes (HUD)  No (HUD)
#
#           Learning   Physical PhysicalMedical VisionImpaired
# ClientID
# 1096      No (HUD)  Yes (HUD)        No (HUD)       No (HUD)
# 2024      No (HUD)   No (HUD)        No (HUD)       No (HUD)
# 2054      No (HUD)  Yes (HUD)        No (HUD)       No (HUD)
# 2142      No (HUD)  Yes (HUD)       Yes (HUD)       No (HUD)
# 2458      No (HUD)   No (HUD)        No (HUD)       No (HUD)
# ...            ...        ...             ...            ...
# 1003586   No (HUD)  Yes (HUD)        No (HUD)       No (HUD)
# 1003772   No (HUD)   No (HUD)        No (HUD)       No (HUD)
# 1004044   No (HUD)  Yes (HUD)        No (HUD)       No (HUD)
# 1004126   No (HUD)   No (HUD)        No (HUD)       No (HUD)
# 1004212   No (HUD)   No (HUD)        No (HUD)       No (HUD)
#
# [1274 rows x 12 columns]

# %%
#Update values to binary values
disability_pivot_df1 = disability_pivot_df.replace(to_replace ="Yes (HUD)", value ="1") 
disability_pivot_df2 = disability_pivot_df1.replace(to_replace ="No (HUD)", value ="0") 

disability_pivot_df2
# Out:
#          AlcoholAbuse AlcoholandDrugAbuse ChronicHealthCondition  \
# ClientID
# 1096                0                   0                      0
# 2024                0                   0                      0
# 2054                0                   0                      0
# 2142                0                   1                      0
# 2458                0                   0                      0
# ...               ...                 ...                    ...
# 1003586             0                   0                      1
# 1003772             0                   0                      0
# 1004044             0                   0                      1
# 1004126             0                   0                      0
# 1004212             0                   1                      0
#
#          Developmental DrugAbuse HIVorAIDS MentalHealthProblem Other Learning  \
# ClientID
# 1096                 0         0         0                   0     0        0
# 2024                 0         0         1                   0     0        0
# 2054                 0         0         0                   1     0        0
# 2142                 0         0         0                   1     0        0
# 2458                 0         0         0                   1     0        0
# ...                ...       ...       ...                 ...   ...      ...
# 1003586              0         0         0                   0     0        0
# 1003772              0         0         0                   1     0        0
# 1004044              0         0         0                   1     0        0
# 1004126              1         0         0                   1     0        0
# 1004212              0         0         0                   1     0        0
#
#          Physical PhysicalMedical VisionImpaired
# ClientID
# 1096            1               0              0
# 2024            0               0              0
# 2054            1               0              0
# 2142            1               1              0
# 2458            0               0              0
# ...           ...             ...            ...
# 1003586         1               0              0
# 1003772         0               0              0
# 1004044         1               0              0
# 1004126         0               0              0
# 1004212         0               0              0
#
# [1274 rows x 12 columns]

# %%
#convert to integer fields

disability_pivot_df2['AlcoholAbuse'] = disability_pivot_df2['AlcoholAbuse'].astype(int)
disability_pivot_df2['AlcoholandDrugAbuse'] = disability_pivot_df2['AlcoholandDrugAbuse'].astype(int)
disability_pivot_df2['ChronicHealthCondition'] = disability_pivot_df2['ChronicHealthCondition'].astype(int)
disability_pivot_df2['Developmental'] = disability_pivot_df2['Developmental'].astype(int)
disability_pivot_df2['Developmental'] = disability_pivot_df2['Developmental'].astype(int)
disability_pivot_df2['DrugAbuse'] = disability_pivot_df2['DrugAbuse'].astype(int)
disability_pivot_df2['HIVorAIDS'] = disability_pivot_df2['HIVorAIDS'].astype(int)
disability_pivot_df2['MentalHealthProblem'] = disability_pivot_df2['MentalHealthProblem'].astype(int)
disability_pivot_df2['Other'] = disability_pivot_df2['Other'].astype(int)
disability_pivot_df2['Learning'] = disability_pivot_df2['Learning'].astype(int)
disability_pivot_df2['Physical'] = disability_pivot_df2['Physical'].astype(int)
disability_pivot_df2['PhysicalMedical'] = disability_pivot_df2['PhysicalMedical'].astype(int)
disability_pivot_df2['VisionImpaired'] = disability_pivot_df2['VisionImpaired'].astype(int)

print (disability_pivot_df2.dtypes)
# Out:
# AlcoholAbuse              int32
# AlcoholandDrugAbuse       int32
# ChronicHealthCondition    int32
# Developmental             int32
# DrugAbuse                 int32
# HIVorAIDS                 int32
# MentalHealthProblem       int32
# Other                     int32
# Learning                  int32
# Physical                  int32
# PhysicalMedical           int32
# VisionImpaired            int32
# dtype: object

# %%
#Sum the number of disabilities

#clear DisabilityTypeTotal before running the sum
disability_pivot_df2['DisabilityTypeTotal'] = 0
disability_pivot_df2['DisabilityTypeTotal'] = disability_pivot_df2.sum(axis = 1)

disability_df = disability_pivot_df2

disability_df
# Out:
#           AlcoholAbuse  AlcoholandDrugAbuse  ChronicHealthCondition  \
# ClientID
# 1096                 0                    0                       0
# 2024                 0                    0                       0
# 2054                 0                    0                       0
# 2142                 0                    1                       0
# 2458                 0                    0                       0
# ...                ...                  ...                     ...
# 1003586              0                    0                       1
# 1003772              0                    0                       0
# 1004044              0                    0                       1
# 1004126              0                    0                       0
# 1004212              0                    1                       0
#
#           Developmental  DrugAbuse  HIVorAIDS  MentalHealthProblem  Other  \
# ClientID
# 1096                  0          0          0                    0      0
# 2024                  0          0          1                    0      0
# 2054                  0          0          0                    1      0
# 2142                  0          0          0                    1      0
# 2458                  0          0          0                    1      0
# ...                 ...        ...        ...                  ...    ...
# 1003586               0          0          0                    0      0
# 1003772               0          0          0                    1      0
# 1004044               0          0          0                    1      0
# 1004126               1          0          0                    1      0
# 1004212               0          0          0                    1      0
#
#           Learning  Physical  PhysicalMedical  VisionImpaired  \
# ClientID
# 1096             0         1                0               0
# 2024             0         0                0               0
# 2054             0         1                0               0
# 2142             0         1                1               0
# 2458             0         0                0               0
# ...            ...       ...              ...             ...
# 1003586          0         1                0               0
# 1003772          0         0                0               0
# 1004044          0         1                0               0
# 1004126          0         0                0               0
# 1004212          0         0                0               0
#
#           DisabilityTypeTotal
# ClientID
# 1096                        1
# 2024                        1
# 2054                        2
# 2142                        4
# 2458                        1
# ...                       ...
# 1003586                     2
# 1003772                     1
# 1004044                     3
# 1004126                     2
# 1004212                     2
#
# [1274 rows x 13 columns]

# %%
#disability_csv = disability_df.to_csv (r'data\disability.csv', index = "ClientID", header=True) #Don't forget to add '.csv' at the end of the path
#disability_read_csv = disability_Yes_df.to_csv (r'data\disability_orig.csv', index = "ClientID", header=True) #Don't forget to add '.csv' at the end of the path

# %%
#Join demographics and disabilities data to create final dataset

master_df = client_df.join(disability_df, how='left', lsuffix='_demo',rsuffix='_dis')

master_df
# Out:
#       ClientID   Age  Gender                    Race                Ethnicity  \
# 0       397941  60.0  Female                   White  Non-Hispanic/Non-Latino
# 1       130335  48.0  Female  Black/African American  Non-Hispanic/Non-Latino
# 2       188933  42.0  Female  Black/African American  Non-Hispanic/Non-Latino
# 3       168290  61.0    Male                   White          Hispanic/Latino
# 4       123122  53.0    Male                   White  Non-Hispanic/Non-Latino
# ...        ...   ...     ...                     ...                      ...
# 2359    376797  51.0    Male  Black/African American  Non-Hispanic/Non-Latino
# 2360    199296  38.0  Female                   White  Non-Hispanic/Non-Latino
# 2361    378312  50.0    Male  Black/African American  Non-Hispanic/Non-Latino
# 2362    379142  33.0    Male                   White  Non-Hispanic/Non-Latino
# 2363    363078  62.0    Male  Black/African American  Non-Hispanic/Non-Latino
#
#      VeteranStatus  AlcoholAbuse  AlcoholandDrugAbuse  ChronicHealthCondition  \
# 0               No           NaN                  NaN                     NaN
# 1               No           NaN                  NaN                     NaN
# 2               No           NaN                  NaN                     NaN
# 3               No           NaN                  NaN                     NaN
# 4               No           NaN                  NaN                     NaN
# ...            ...           ...                  ...                     ...
# 2359            No           NaN                  NaN                     NaN
# 2360            No           NaN                  NaN                     NaN
# 2361            No           NaN                  NaN                     NaN
# 2362            No           NaN                  NaN                     NaN
# 2363           Yes           NaN                  NaN                     NaN
#
#       Developmental  DrugAbuse  HIVorAIDS  MentalHealthProblem  Other  \
# 0               NaN        NaN        NaN                  NaN    NaN
# 1               NaN        NaN        NaN                  NaN    NaN
# 2               NaN        NaN        NaN                  NaN    NaN
# 3               NaN        NaN        NaN                  NaN    NaN
# 4               NaN        NaN        NaN                  NaN    NaN
# ...             ...        ...        ...                  ...    ...
# 2359            NaN        NaN        NaN                  NaN    NaN
# 2360            NaN        NaN        NaN                  NaN    NaN
# 2361            NaN        NaN        NaN                  NaN    NaN
# 2362            NaN        NaN        NaN                  NaN    NaN
# 2363            NaN        NaN        NaN                  NaN    NaN
#
#       Learning  Physical  PhysicalMedical  VisionImpaired  DisabilityTypeTotal
# 0          NaN       NaN              NaN             NaN                  NaN
# 1          NaN       NaN              NaN             NaN                  NaN
# 2          NaN       NaN              NaN             NaN                  NaN
# 3          NaN       NaN              NaN             NaN                  NaN
# 4          NaN       NaN              NaN             NaN                  NaN
# ...        ...       ...              ...             ...                  ...
# 2359       NaN       NaN              NaN             NaN                  NaN
# 2360       NaN       NaN              NaN             NaN                  NaN
# 2361       NaN       NaN              NaN             NaN                  NaN
# 2362       NaN       NaN              NaN             NaN                  NaN
# 2363       NaN       NaN              NaN             NaN                  NaN
#
# [2364 rows x 19 columns]

# %%
master_csv = master_df.to_csv (r'..\data\master.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
